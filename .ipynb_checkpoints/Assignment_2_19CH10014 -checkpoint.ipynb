# %%
#Assignment 2 Awais Akhtar (19CH10014)

# %%
import pandas as pd
import numpy as np
import random

# %%
dataset = pd.read_csv('Advertising Dataset.csv')
from sklearn.utils import shuffle
dataset = shuffle(dataset)
dataset
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 106         107   25.0   11.0       29.7    7.2
# 198         199  283.6   42.0       66.2   25.5
# 47           48  239.9   41.5       18.5   23.2
# 7             8  120.2   19.6       11.6   13.2
# 53           54  182.6   46.2       58.7   21.2
# ..          ...    ...    ...        ...    ...
# 145         146  140.3    1.9        9.0   10.3
# 184         185  253.8   21.3       30.0   17.6
# 197         198  177.0    9.3        6.4   12.8
# 100         101  222.4    4.3       49.8   11.7
# 161         162   85.7   35.8       49.3   13.3
#
# [200 rows x 5 columns]

# %%
training_set = dataset.iloc[:int(dataset.shape[0]*0.75)]
test_set = dataset.iloc[int(dataset.shape[0]*0.75):]
cols = len(training_set.iloc[0])
test_set
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 28           29  248.8   27.1       22.9   18.9
# 18           19   69.2   20.5       18.3   11.3
# 89           90  109.8   47.8       51.4   16.7
# 190         191   39.5   41.1        5.8   10.8
# 40           41  202.5   22.3       31.6   16.6
# 32           33   97.2    1.5       30.0    9.6
# 191         192   75.5   10.8        6.0    9.9
# 72           73   26.8   33.0       19.3    8.8
# 12           13   23.8   35.1       65.9    9.2
# 171         172  164.5   20.9       47.4   14.5
# 169         170  284.3   10.6        6.4   15.0
# 173         174  168.4    7.1       12.8   11.7
# 118         119  125.7   36.9       79.2   15.9
# 152         153  197.6   23.3       14.2   16.6
# 74           75  213.4   24.6       13.1   17.0
# 27           28  240.1   16.7       22.9   15.9
# 33           34  265.6   20.0        0.3   17.4
# 179         180  165.6   10.0       17.6   12.6
# 0             1  230.1   37.8       69.2   22.1
# ...

# %%
y_train = training_set.loc[:,training_set.columns[cols-1]]
y_train = pd.DataFrame(y_train)
y_train
# Out:
#      sales
# 106    7.2
# 198   25.5
# 47    23.2
# 7     13.2
# 53    21.2
# ..     ...
# 139   20.7
# 52    22.6
# 133   19.6
# 177   11.7
# 2      9.3
#
# [150 rows x 1 columns]

# %%
x_train = training_set.loc[:,training_set.columns[1:cols-1]]
x_train
# Out:
#         TV  radio  newspaper
# 106   25.0   11.0       29.7
# 198  283.6   42.0       66.2
# 47   239.9   41.5       18.5
# 7    120.2   19.6       11.6
# 53   182.6   46.2       58.7
# ..     ...    ...        ...
# 139  184.9   43.9        1.7
# 52   216.4   41.7       39.6
# 133  219.8   33.5       45.1
# 177  170.2    7.8       35.2
# 2     17.2   45.9       69.3
#
# [150 rows x 3 columns]

# %%
x_mean = np.mean(x_train)
x_mean = pd.DataFrame(x_mean).T

y_mean = np.mean(y_train)

n=len(x_train)

# %%
x_bar = x_train.copy()
y_bar = y_train.copy()

for i in range(n):
    x_bar.iloc[i] = x_train.iloc[i] - x_mean.iloc[0]
    y_bar.iloc[i] = y_train.iloc[i] - y_mean.iloc[0]

# %%
denominator = np.linalg.inv((x_bar.T).dot(x_bar))
denominator
# Out:
# array([[ 9.24832686e-07, -4.91097879e-07, -2.42748350e-08],
#        [-4.91097879e-07,  3.23169759e-05, -7.36140914e-06],
#        [-2.42748350e-08, -7.36140914e-06,  1.68712602e-05]])

# %%
numerator = (x_bar.T).dot(y_bar)
numerator = np.array(numerator)
numerator
# Out:
# array([[54253.3632],
#        [ 7520.9146],
#        [ 2946.2114]])

# %%
W = denominator.dot(numerator)
b = y_mean - np.array(x_mean.dot(W))[0]
print("Co-efficients of the hypothesis using formula are")
for i in range(len(W)):
    print(W[i][0])
print("Intercept of the hypothesis using formula : {}".format(b[0]))
W
# Out:
# Co-efficients of the hypothesis using formula are
# 0.046410259596613414
# 0.19472123650711054
# -0.006975221723363775
# Intercept of the hypothesis using formula : 2.9514694604763125
# array([[ 0.04641026],
#        [ 0.19472124],
#        [-0.00697522]])

# %%
#using python library
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression().fit(x_train, y_train)
c = reg.coef_
print("Co-efficients of the hypothesis using formula are")
for i in range(len(c[0])):
    print(c[0][i])
print("Intercept of the hypothesis using library : {}".format(reg.intercept_[0]))
# Out:
# Co-efficients of the hypothesis using formula are
# 0.04641025959661339
# 0.19472123650711037
# -0.006975221723363831
# Intercept of the hypothesis using library : 2.9514694604763214

# %%
x_test = test_set.loc[:,test_set.columns[1:cols-1]]
y_test = test_set.loc[:,test_set.columns[cols-1]]
y_test = pd.DataFrame(y_test)

def mean_error(x,y,w,b):
    m = len(x)
    error = np.array(y) - np.array(x).dot(w) - b[0]
    sqlerror = error**2
    mean_sql_error = sum(sqlerror)/m
    return mean_sql_error
    
mean_sql_error = mean_error(x_train,y_train,W ,b)
    
print("Mean square error is {} ".format(mean_sql_error[0]))
# Out:
# Mean square error is 2.429017447207793

# %%
# Ridge Regression

lam = [0.5,1,5,10,100,10000,50000,100000,500000,1000000] #lambda value was increase to get a curve while

w_ridge = []
b_ridge = []
mean_sql_errors = []

d = len(x_train.iloc[0])
for i in range(len(lam)):
    deno = np.linalg.inv((x_bar.T).dot(x_bar) + lam[i]*np.identity(d))
    numer = np.array((x_bar.T).dot(y_bar))
    w_ridge.append(deno.dot(numer))
    b_ridge.append(y_mean - np.array(x_mean.dot(w_ridge[i]))[0])
    mean_sql_errors.append(list(mean_error(x_test,y_test,w_ridge[i],b_ridge[i]))[0])

mean_coeff = [ np.mean(arr) for arr in w_ridge]
max_coeff = [np.max(arr) for arr in w_ridge]
print(mean_sql_errors)
print(mean_coeff)
print(max_coeff)
# Out:
# [3.946990391764073, 3.9469606092015885, 3.9467224956414357, 3.9464252208332526, 3.9411436227898586, 3.84674628265641, 5.060642253037267, 6.064531637988642, 8.5346935610525, 10.397302332394947]
# [0.07805130537331684, 0.07805051930982972, 0.0780442316411737, 0.07803637415280325, 0.07789533658848911, 0.0658528333725772, 0.044726560167094975, 0.034592815185489866, 0.01698064748829965, 0.011686925805485469]
# [0.1947180758825535, 0.1947149153658606, 0.19468963511475057, 0.19465804450373822, 0.19409125072167302, 0.14752149544705473, 0.07649319090906197, 0.04839524530688177, 0.03391189273091171, 0.02586742648757743]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(lam,mean_coeff,'bo-')
plt.xlabel('Lambda')
plt.ylabel('Coefficients')
plt.title('Mean Coefficients Vs Lambda')
plt.show()

# %%
plt.plot(lam,mean_sql_errors,'co-')
plt.xlabel('Lambda')
plt.ylabel('Mean Square Errors')
plt.title('Mean Square Errors Vs Lambda')
plt.show()

# %%
plt.plot(lam,max_coeff,'go-')
plt.xlabel('Lambda')
plt.ylabel('Co-efficients')
plt.title('Max Co-efficients Vs Lambda')
plt.show()

# %%
from sklearn.linear_model import Lasso

# %%
coeff_ind = []
for val in lam[:5]: #sliced because we had to cosider only the first five values of lambda to find the most imp feature
    reg = Lasso(alpha = val)
    reg.fit(x_train, y_train)
    value = [bit for bit in reg.coef_]
    index  = value.index(max(value))
    coeff_ind.append(index)
    
most_imp = max(coeff_ind, key=coeff_ind.count)
most_imp
# Out:
# 1

# %%
imp_col = dataset.columns[most_imp+1] # +1 is done because data set also includes serial number but we are not including it
imp_col
# Out:
# 'radio'

# %%
print("The most important feature is {} which is at {}th position according to Lasso Regression ".format(imp_col,most_imp))
# Out:
# The most important feature is radio which is at 1th position according to Lasso Regression
